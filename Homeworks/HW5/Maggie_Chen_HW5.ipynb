# %% [markdown]
# # DS4200 Homework 5
#
# Due: Friday Feb 13th @ 11:59 PM EST
#
# ### Submission Instructions
# Submit this `ipynb` file included with the coding results as well as all required pictures in the question to Gradescope (this can also be done via the assignment on Canvas). Rename all files to include your name. To ensure that your submitted files represent your latest code, make sure to give a fresh `Kernel > Restart & Run All` just before uploading the files to gradescope.
#
# Please email the instructor if you have problems to complete the color-related homework.
#
# ### Tips for success
# - Start early
# - Make use of Piazza
# - Make use of Office hour
# - Remember to use cells and headings to make the notebook easy to read (if a grader cannot find the answer to a problem, you will receive no points for it)
# - Under no circumstances may one student view or share their ungraded homework or quiz with another student [(see also)](http://www.northeastern.edu/osccr/academic-integrity), though you are welcome to **talk about** (not show each other) the problems.

# %% [markdown]
# ### Part 1 - Colors (40 points)
#
# ##### Question 1 (9 points)
#
# **Viridis** is one of the most popular (and sometimes default) colormaps in Python because it is **perceptually uniform** and **color-blind friendly**. It is generally a safe choice, but it may **not always be the best choice** for every task.
#
# Below are two choropleth maps of the **unemployment rate in the lower 48 U.S. states**, created using **Plotly**. The **color legends are hidden**.
#
# Consider the following questions (you do **not** need to answer them). For **each question**, think about which colormap—**Viridis** or **Blues**—would be **more helpful** for supporting the task, and why.
#
# - Compare **California** and **Nevada**: which state has a higher unemployment rate?
# - Identify the states with the **highest** and **lowest** unemployment rates.
# - Determine whether there is any **spatial clustering pattern** in unemployment rates across states.
#
# > **Note:** If you are interested in the underlying values, the dataset is provided as a CSV file attached to the homework.

# %% [markdown]
# <div style="display: flex; gap: 12px;">
#   <img src="https://i.ibb.co/27Gb81cb/viridis.png" width="49%">
#   <img src="https://i.ibb.co/whXjm6m4/blues.png" width="49%">
# </div>

# %% [markdown]
# In the blue map I can clearly tell that California has the higher unemployment rate compared to Nevada. While in the Virdis map its hard to tell which one has higher unemployment due to the different ranges of shades but I would say the Nevada has the higher unemployemnt rate.
#
# In the blue map the state with the highest umemployment is Mississippi, Alabama, and West Virgina because they are the darkest shade of blue. The state with the lowest rate is Virginia, South Dakota, and Massaschusetts.While in the Virdis map everything is essentially the opposite of the blue map. Where in the blue map the states that have lower rates would have higher rates in the virdis maps abd vice versa.
#
# Yes, there is spatial clustering in unemployement rates across states. Both the maps show clustering around the moutain west/great plains region, which have lower rates, and higher rates in upper midwest.

# %% [markdown]
# ##### Question 2 (6 points)
#
# The figure below shows a **density plot** of **wind speed** for all five weather types.
#
# - Are there any **problems or limitations** with this visualization?
# - Identify **at least two ways** you could **redesign** the figure to improve clarity or effectiveness.
#   You may consider changes to the **mark**, **visual channels**, or **encodings** (e.g., color choice, overlap handling, faceting, transparency, or alternative plot types).

# %% [markdown]
# <img src="https://i.ibb.co/QNfQ2tb/visualization.png" alt="visualization" border="0">

# %% [markdown]
# Problems/Limitations
# * severe overlaop: filled density curves overlap hevaily, making fog and rain for example nearly invisible to see, you can't compare all five of them
# * misleading title: it says sun, drizzle, and snow but it inclues all five weather types
# * no quantitative reference: there is no easy wayt to idenfity medians, means, or range for comparisions.
#
# Redesigns
# * change to box plot or violin plot: shows all five weather types side by side without overlap
# * use small mutliples: create five separate panesl, one for each weather type

# %% [markdown]
# ##### Question 3 (5 points)
#
# Visit [http://vrl.cs.brown.edu/color](http://vrl.cs.brown.edu/color) and select an **alternative color palette** for the figure in **Question 2**.
#
# - Explain **how you configured the tool** to obtain the chosen color palette (e.g., number of colors, color type, constraints).
# - Take a **screenshot of the selected palette** and **attach it with your submission**.
# - Then go to the [Color Blindness Simulator (Coblis)](https://www.color-blindness.com/coblis-color-blindness-simulator/) and upload the screenshot.
# - Choose **one type of color-vision deficiency** and discuss **how it affects the readability or interpretation** of the figure when using your selected palette.

# %% [markdown]
# Configurations
# * 5 colors
# * qualitative palette because the categories are weather types
# * perceptual distance: set high to maximize distinguishabilty between the colors
# * name differece: set to medium to esnure colors have distinct easily identifiable names
# * pair preference: set to moderate to balance aesthic appeal
# * anem uniqueness: set to medium for clear color identification
# * everything else left on default.

# %% [markdown]
# ![Color Palette](question3_color_palette.png)

# %% [markdown]
# ![Protanopia Simulation](question3_colorblind_test.png)

# %% [markdown]
# I choose red-blind/protanopia.
# * Colors that remain distinct: the cyan [rgb(141,228,211)] and bright green [rgb(83,224,120)] stay distinguishable since they don't rely on red wavelengths.
# * Problematic color pairs: the magenta [rgb(166,0,62)] and brown/mauve [rgb(106,55,71)] become nearly identical dark gray/brown tones, making it difficult to differentiate between their corresponding weather categories.
# * Yellow-green shift: the lime color [rgb(177,211,79)] appears more yellowish-beige but remains somewhat visible.
# * Overall impact: for protanopia users, the palette effectively reduces from 5 distinct colors to only 3-4 distinguishable colors. This creates confusion in overlapping areas of the density plot where red-based weather categories intersect, making accurate interpretation challenging.

# %% [markdown]
# ##### Question 4 (10 points)
#
# Based on what we learned in lecture, create your **own example of a color illusion**. Choose **one** of the following illusion types:
#
# - **Simultaneous Contrast:** A color appears different depending on surrounding light/dark colors.
# - **Gradient Illusion:** A gradient background changes how a solid color in front of it is perceived.
# - **Color Context Effects:** The same color can appear lighter/darker or even shift hue depending on its context (e.g., borders or nearby colors).
#
# **Submission:**
# - **Attach an image of your design to the homework submission.**
# - You may use **any tool** to create the design (e.g., PowerPoint, Canva, Photoshop, Figma, etc.).
# - Do **not** directly copy the examples from the lecture—your design should be original.
#
# **Written response (a few sentences):**
# In your write-up, briefly describe:
# - how you designed the illusion (what elements/colors you chose and how they are arranged), and
# - which illusion type you are demonstrating and why your design produces that effect.

# %% [markdown]
# ![Simultaneous Contrast Illusion](./simultaneous_contrasts_illusion.png)

# %% [markdown]
# **Response**
#
# I created a simultaneous contrast illusion using two identical medium gray squares placed on contrasting backgrounds, one on a dark charcoal background and one on a light gray background. This demonstrates simultaneous contrast because our visual system perceives colors relative to their surroundings. The identical gray square appears lighter on the dark background and darker on the light background, even though both squares are exactly the same color value.

# %% [markdown]
# ##### Question 5 (10 points)
# In the following cases, each item describes a **feature**. Depending on the **visualization task**, the feature can be encoded using different types of **colormaps** (e.g., sequential, diverging, categorical).
#
# For **each feature and colormap choice**, use **one sentence** to describe a **task** that the colormap would be well suited to support.
#
# **Example:**
#
# - **Feature:** Exam score (0 to 100), numerical feature
#   - **Sequential:** Compare students’ scores directly (e.g., who has a higher or lower score).
#   - **Diverging:** Identify students who fail the exam by checking whether their scores fall below a threshold (e.g., 60).
#   - **Categorical:** Convert students' scores into letter grades (A,B,C,D) and represent the letter grades
#
# Follow this format for the features listed below.

# %% [markdown]
# - **Feature:** Voting margin between two parties by district (numerical), shown on a map
#   - **Sequential:**
#   - **Diverging:**

# %% [markdown]
# - **Feature:** Sentiment score (−1 to 1), numerical feature
#   - **Sequential:**
#   - **Diverging:**
#   - **Categorical:**

# %% [markdown]
# Feature 1: voting margin between 2 parties by district (numerical), shown on a map
# * sequential: show which party won each distrcit by a greater margin, ranging from small/light to large/dark margins for the winning party
# * diverging: highlight competitive districts by showing margins for party A/red in one color directions, and party B/Blue in the opposite direction, with nuetral/white representing tie districts
#
# Feature 2: sentiment score(-1 to 1), numerical feature
# * sequential: display sentiment intensity from neutral, 0, to strongly positive, 1, using a single color gradient to show increasing positivity
# fiverging: distinguish between negative sentiment,-1 show in one color like red, nuetral, 0 white/gray, and postive sentiment, 1 opposite colors, to emphasize the direction of sentiment
# * categorical: group sentiment into discrte categories (negative, neutral, positive), and assign distinct colors to each category for clear identification

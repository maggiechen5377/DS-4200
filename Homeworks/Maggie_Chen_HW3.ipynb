# %% [markdown]
# # DS4200 Homework 3
#
# Due: Friday Jan 30th @ 11:59 PM EST
#
# ### Submission Instructions
# Submit this `ipynb` file included with the coding results as well as the picture in the last question to Gradescope (this can also be done via the assignment on Canvas).  To ensure that your submitted files represent your latest code, make sure to give a fresh `Kernel > Restart & Run All` just before uploading the files to gradescope.
#
# ### Tips for success
# - Start early
# - Make use of Piazza
# - Make use of Office hour
# - Remember to use cells and headings to make the notebook easy to read (if a grader cannot find the answer to a problem, you will receive no points for it)
# - Under no circumstances may one student view or share their ungraded homework or quiz with another student [(see also)](http://www.northeastern.edu/osccr/academic-integrity), though you are welcome to **talk about** (not show each other) the problems.

# %% [markdown]
# ### Part 1 - Basic data analysis with Altair (50 points)
#
# In this assignment, you will use the **same Weather dataset from Homework 1**, but create all visualizations using **Altair**.
#
# For **each question**, write the **Altair code** needed to generate the visualization. Every figure must include an **in-figure title and axis labels**. Adjust the figure size if necessary.
#
# In addition, for **each figure**, you must:
# - Identify the **mark(s)** used in the visualization.
# - Identify the **visual channel(s)** used.
# - Explain **which data feature** is encoded by each channel.
#
# No need to describe the figure nor write comments for the code.
#
# > **Note on AI use:**
# > If you experience difficulty with the coding, please **seek help from the instructor or TAs first**. If you choose to use AI tools to complete any part of the homework, you must clearly state **which part you struggled with** and **how AI was used** in your written response.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import altair as alt
from vega_datasets import data

weather = data.seattle_weather()
weather.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %% [markdown]
# ##### Question 1 (10 points)
#
# Recreate the figure from **Homework 1, Part 2 – Question 2** using **Altair**.
#
# Specifically:
# - Create a **side-by-side boxplot** that shows the relationship between **maximum temperature** and **weather type**.
# - Include appropriate **titles** and **axis labels** in the figure.

# %% [markdown]
# ##### Question 2 (10 points)
#
# Recreate the figure from **Homework 1, Part 2 – Question 3** using **Altair**.
#
# Specifically:
# - Create a **scatter plot** that shows the relationship between **maximum temperature** and **minimum temperature**.
# - Use **color** to distinguish different **weather types**.
# - Include appropriate **titles** and **axis labels** in the figure.

# %% [markdown]
# ##### Question 3 (10 points)
#
# Create an **area plot** that visualizes **average wind speed** and **precipitation**. Compute the averages directly within your code using `average()` or `mean()`.
#
# - In the **y-channel**, set the parameter `stack='center'` to center the stacked areas.
# - Use **color** to distinguish different **weather types**.
#
# > **Note:** The resulting visualization is called a [**streamgraph**](https://en.wikipedia.org/wiki/Streamgraph). We will discuss this figure next week in the lecture.

# %% [markdown]
# ##### Question 4 (10 points)
#
# Create a **faceted visualization** in **Altair** with **2 rows and 3 columns**.
#
# - Each facet should display a **scatter plot** showing the relationship between **maximum temperature** and **minimum temperature** for **one weather type**.
# - One of the six panels will remain **empty**, which is expected.
# - Encode **wind speed** using **color**. (You can try the size encode too to think about why color may be preferred in this case)
# - Add some opacity to the plot if necessary.
# - Add a **tooltip** to each point that shows:
#   - maximum temperature,
#   - minimum temperature, and
#   - wind speed.
# - Include appropriate **titles** and **axis labels** for the figure.

# %% [markdown]
# ##### Question 5 (10 points)
#
# Create a **compound visualization** using **at least two different types of marks**.
#
# - Visualize the **trend of average temperature** over **four years**, where average temperature is computed as the mean of the **minimum and maximum temperatures**.
# - Use the **`date` field** directly as the **x-axis** (do not aggregate the data by year), which will result in a wide figure.
# - Include appropriate **titles** and **axis labels** for the visualization.
